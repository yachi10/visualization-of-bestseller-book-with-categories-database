# %% [markdown]
# # ***Data Visualization*** ***using seborn***

# %%
pip install seaborn

# %%
pip install numpy

# %%
pip install pandas

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv("/content/bestsellers with categories.csv", encoding = "latin-1")
data.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# import module
import seaborn as sns
import pandas

# loading csv
data = pandas.read_csv("/content/bestsellers with categories.csv")

# plotting lineplot
sns.lineplot( x = "Reviews", y = "Price", data = data )
# Out:
# <Axes: xlabel='Reviews', ylabel='Price'>

# %%
# import module
import seaborn as sns
import pandas

# loading csv
data = pandas.read_csv("/content/bestsellers with categories.csv")

# plotting lineplot
sns.lineplot( x = "Reviews", y = "Year", data = data )
# Out:
# <Axes: xlabel='Reviews', ylabel='Year'>

# %%
# import module
import seaborn as sns
import pandas

# loading csv
data = pandas.read_csv("/content/bestsellers with categories.csv")

# plotting lineplot
sns.lineplot( x = "Reviews", y = "Genre", data = data )
# Out:
# <Axes: xlabel='Reviews', ylabel='Genre'>

# %%
# import module
import seaborn as sns
import pandas

# loading csv
data = pandas.read_csv("/content/bestsellers with categories.csv")

# plotting lineplot
sns.barplot( x = "Reviews", y = "Price", data = data )
# Out:
# <Axes: xlabel='Reviews', ylabel='Price'>

# %%
# import module
import seaborn as sns
import pandas

# loading csv
data = pandas.read_csv("/content/bestsellers with categories.csv")

# plotting lineplot
sns.barplot( x = "Reviews", y = "Year", data = data )
# Out:
# <Axes: xlabel='Reviews', ylabel='Year'>

# %%
# import module
import seaborn as sns
import pandas

# loading csv
data = pandas.read_csv("/content/bestsellers with categories.csv")

# plotting lineplot
sns.scatterplot( x = "Reviews", y = "Price", data = data )
# Out:
# <Axes: xlabel='Reviews', ylabel='Price'>

# %%
# import module
import seaborn as sns
import pandas

# loading csv
data = pandas.read_csv("/content/bestsellers with categories.csv")

# plotting lineplot
sns.scatterplot( x = "Reviews", y = "Year", data = data )
# Out:
# <Axes: xlabel='Reviews', ylabel='Year'>

# %%
# import module
import seaborn as sns
import pandas

# loading csv
data = pandas.read_csv("/content/bestsellers with categories.csv")

# plotting lineplot
sns.boxenplot( x = "Reviews", y = "Price", data = data )
# Out:
# <Axes: xlabel='Reviews', ylabel='Price'>

# %%
# import module
import seaborn as sns
import pandas

# loading csv
data = pandas.read_csv("/content/bestsellers with categories.csv")

# plotting lineplot
sns.boxenplot( x = "Year", y = "Price", data = data )
# Out:
# <Axes: xlabel='Year', ylabel='Price'>

# %%
# import module
import seaborn as sns
import pandas

# loading csv
data = pandas.read_csv("/content/bestsellers with categories.csv")

# plotting lineplot
sns.boxenplot( x = "Price", y = "Genre", data = data )
# Out:
# <Axes: xlabel='Price', ylabel='Genre'>

# %%
sns.pointplot( x = "Reviews", y = "Price", data = data )
# Out:
# <Axes: xlabel='Reviews', ylabel='Price'>

# %%
sns.pointplot( x = "Reviews", y = "Year", data = data )
# Out:
# <Axes: xlabel='Reviews', ylabel='Year'>

# %%
sns.pointplot( x = "Genre", y = "Price", data = data )
# Out:
# <Axes: xlabel='Genre', ylabel='Price'>

# %%
sns.countplot(data['Price'] )
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data['Year'] )
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data['User Rating'] )
# Out:
# <Axes: ylabel='count'>

# %%
sns.violinplot(data['Price'] )
# Out:
# <Axes: >

# %%
sns.violinplot(data['Year'] )
# Out:
# <Axes: >

# %%
sns.swarmplot(data['Price'] )
# Out:
# <Axes: ylabel='Price'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 13.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot( x = "Genre", y = "Price", data = data )
# Out:
# <Axes: xlabel='Genre', ylabel='Price'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 17.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 17.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.pointplot( x = "Genre", y = "Year", data = data )
# Out:
# <Axes: xlabel='Genre', ylabel='Year'>

# %%
sns.distplot(data['Price'])
# Out:
# <ipython-input-33-049e7ab17fe1>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(data['Year'])
# Out:
# <ipython-input-34-cd39e0b988bc>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Year'])
# <Axes: xlabel='Year', ylabel='Density'>

# %%
sns.distplot(data['User Rating'])
# Out:
# <ipython-input-36-c3dc809f18e1>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['User Rating'])
# <Axes: xlabel='User Rating', ylabel='Density'>

# %%
sns.kdeplot(data['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(data['Year'])
# Out:
# <ipython-input-38-cd39e0b988bc>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Year'])
# <Axes: xlabel='Year', ylabel='Density'>

# %%
sns.distplot(data['Reviews'])
# Out:
# <ipython-input-39-a6fd505e2465>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Reviews'])
# <Axes: xlabel='Reviews', ylabel='Density'>

# %%
sns.distplot(data['User Rating'])
# Out:
# <ipython-input-40-c3dc809f18e1>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['User Rating'])
# <Axes: xlabel='User Rating', ylabel='Density'>
